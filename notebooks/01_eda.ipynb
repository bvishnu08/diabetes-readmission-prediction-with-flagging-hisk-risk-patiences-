# %% [markdown]
# # EDA notebook - placeholder
#
# This notebook will contain exploratory data analysis for the diabetes readmission dataset.

# %%
import pandas as pd
from src.config import DIABETIC_CSV

df = pd.read_csv(DIABETIC_CSV, dtype=str)
df.head()
